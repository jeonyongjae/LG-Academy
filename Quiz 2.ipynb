# %% [markdown]
# # t-Test 기준 <span style='background-color: #ffdce0'>하위 특징 10개</span>를 이용한 ANN 학습

# %% [markdown]
# ## ! P_value_Rank 데이터 내림차순 정렬

# %% [markdown]
# - 하위특징 첫번째에 대한 pdf 그래프 확인
# - PCA 적용시 누적 분산 비율 그래프 및 PCA 결과 산점도 확인
# - 학습 중 정확도 그래프 확인
# - 검증 데이터 기반 검증 성능 확인
